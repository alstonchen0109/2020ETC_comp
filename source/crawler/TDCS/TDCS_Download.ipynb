# %%
import requests
from pathlib import Path

#確認該 url 是否可以下載, 例如 20190230 就不存在, 無法下載
def isDownloadable(url):
    """
    Does the url contain a downloadable resource
    """
    h = requests.head(url, allow_redirects=True)
    header = h.headers
    content_type = header.get('content-type')
    if content_type is None:
        return False
    if 'text' in content_type.lower():
        return False
    if 'html' in content_type.lower():
        return False
    return True

#下載某url檔案後, 放在指定目錄下
def downloadFileFromUrl(url, directory):
    r = requests.get(url, allow_redirects=True)
    filename = directory+'/'+ url.rsplit('/', 1)[1]
    open(filename, 'wb').write(r.content)

# %%
#抓取某類型的某一年份所有可能的檔案
def getDownloadList(urlBase, trType, year):
    downloads=[]
    for m in range(1,13):
        for d in range(1,32):
            downloads.append(urlBase + '/' + trType + '/' + trType + '_' + year + format(m, '02d')+ format(d, '02d')+'.tar.gz' ) 
    return downloads

# %%
#要批量下載的類型
#trTypes=['M03A', 'M04A', 'M05A', 'M06A', 'M07A', 'M08A']
trTypes=['M06A']
for t in trTypes:
    fileUrls=getDownloadList('http://tisvcloud.freeway.gov.tw/history/TDCS',t,'2019')

    Path(t).mkdir(parents=True, exist_ok=True)
    for url in fileUrls:
        if isDownloadable(url):
            print(url)
            downloadFileFromUrl(url,t)
# Out:
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190101.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190102.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190103.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190104.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190105.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190106.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190107.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190108.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190109.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190110.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190111.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190112.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190113.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190114.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190115.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190116.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190117.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190118.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190119.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190120.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190121.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190122.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190123.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190124.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190125.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190126.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190127.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190128.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190129.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190130.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190131.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190201.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190202.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190203.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190204.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190205.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190206.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190207.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190208.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190209.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190210.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190211.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190212.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190213.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190214.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190215.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190216.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190217.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190218.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190219.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190220.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190221.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190222.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190223.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190224.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190225.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190226.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190227.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190228.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190301.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190302.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190303.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190304.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190305.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190306.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190307.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190308.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190309.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190310.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190311.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190312.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190313.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190314.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190315.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190316.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190317.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190318.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190319.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190320.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190321.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190322.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190323.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190324.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190325.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190326.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190327.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190328.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190329.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190330.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190331.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190401.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190402.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190403.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190404.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190405.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190406.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190407.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190408.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190409.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190410.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190411.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190412.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190413.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190414.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190415.tar.gz
# http://tisvcloud.freeway.gov.tw/history/TDCS/M06A/M06A_20190416.tar.gz
