# %%
import pandas as pd
import io
import json
import pymongo
import dns

client = pymongo.MongoClient("mongodb+srv://commonUser:riSHPB4shR9WtYwn@cluster0-gzigj.gcp.mongodb.net/traffic?retryWrites=true&w=majority")
    #  commonUser   riSHPB4shR9WtYwn
db = client.traffic
trType='cms'

collect = db[trType+'History']

# %%
def read_mongo(db, collection, query={}, projection={}, no_id=True):
    """ Read from Mongo and Store into DataFrame """
    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query,projection)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
import re

rgx = re.compile('.*火燒車.*', re.IGNORECASE) #, re.IGNORECASE) /.*火燒車.*/
collect = db['cmsHistory']
#query = {"@message": rgx}
query = {"@message": {'$regex':'.*火燒車.*'}}
projection = {"@message":1, "@cmsid":1}
cursor = collect.find(query, projection)
for doc in cursor:
    print(doc['@message'],doc['@cmsid'])
# Out:
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M
# 高架 60ｋ  外側 火燒車 nfbCMS-N1-S-55.780-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-53.845-M
# 國1(圖)高架 60ｋ  外側 火燒車 nfbCMS-N1H-S-56.920-M
# 國1(圖)高架南向60ｋ外側 火燒車 nfbCMS-N2-E-7.452-M

# %%
df=read_mongo(db,"cmsHistory",{"@message": ".*火燒車.*"},projection={"@message":1}) 
#df=read_mongo(db,"cmsHistory",{"@message": {'$regex':'火燒車'}},projection={"@message":1})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/hans/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-84602106076e> in <module>
# ----> 1 df=read_mongo(db,"cmsHistory",{"@message": ".*火燒車.*"},projection={"@message":1})
#       2 #df=read_mongo(db,"cmsHistory",{"@message": {'$regex':'火燒車'}},projection={"@message":1})
#
# <ipython-input-2-7f5c81e2612f> in read_mongo(db, collection, query, projection, no_id)
#       9     # Delete the _id
#      10     if no_id:
# ---> 11         del df['_id']
#      12
#      13     return df
#
# ~/miniconda3/envs/hans/lib/python3.7/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~/miniconda3/envs/hans/lib/python3.7/site-packages/pandas/core/internals/managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/miniconda3/envs/hans/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_id'

# %%
df

# %%
df=read_mongo(db,"VDLive", {"LinkFlows.LinkFlow.LinkID":"1008200100940Q"} ,{"VDID":1,"LinkFlows.LinkFlow.LinkID":1,"LinkFlows.LinkFlow.Lanes.Lane.Speed":1})

# %%
collect = db['VDLive']
query = {"LinkFlows.LinkFlow.LinkID":"1008200100940Q"}
projection = {"VDID":1,"LinkFlows.LinkFlow.LinkID":1,"LinkFlows.LinkFlow.Lanes.Lane.Speed":1}
cursor = collect.find(query)
for doc in cursor:
    print(doc['LinkFlows']['LinkFlow']['Lanes']['Lane']['Vehicles']['Vehicle'][0])
    break
