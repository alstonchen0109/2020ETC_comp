# %%
import gzip
import pandas as pd
import io
import xmltodict
import json
import pymongo
import dns
from os import listdir
from os.path import isfile, join

client = pymongo.MongoClient("mongodb+srv://commonUser:riSHPB4shR9WtYwn@cluster0-gzigj.gcp.mongodb.net/traffic?retryWrites=true&w=majority")
    #  commonUser   riSHPB4shR9WtYwn
db = client.traffic
trType='cms'

collect = db[trType+'History']

# %%
def ungzToMongoDB(gzFile):

    f = gzip.open(gzFile, 'rb')
    doc = xmltodict.parse(f)
    #print(doc)
    X=doc['XML_Head']['Infos']['Info']
    updateTime=doc['XML_Head']['@updatetime']
    json_data = json.dumps(X)
    cc = json.loads(json_data)
    for a in cc:
        a['updateTime']=updateTime
    #print(cc)
    #df = pd.json_normalize(cc)
    
    collect.insert_many(cc)
    f.close()
    
    #return df

# %%
def getAllFiles2Mongo(directory):
    files = [f for f in listdir(directory) if isfile(join(directory, f))]
    #print(files)
    for file in files:
        f = gzip.open(directory+file, 'rb')
        doc = xmltodict.parse(f)
        #print(doc)
        X=doc['XML_Head']['Infos']['Info']
        json_data = json.dumps(X)
        cc = json.loads(json_data)
        #print(cc)
        #df = pd.json_normalize(cc)

        collect.insert_many(cc)
        f.close()

# %%
getAllFiles2Mongo('../../../data/'+trType+'_0101/')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-70c116e8c37a> in <module>
# ----> 1 getAllFiles2Mongo('../../../data/'+trType+'_0101/')
#
# <ipython-input-8-916065ceaaf4> in getAllFiles2Mongo(directory)
#       6         doc = xmltodict.parse(f)
#       7         #print(doc)
# ----> 8         X=doc['XML_Head']['Infos']['Info']
#       9         json_data = json.dumps(X)
#      10         cc = json.loads(json_data)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
#                                                        0
# 0                 <?xml version="1.0" encoding="utf-8"?>
# 1      <XML_Head version="1.1" listname="VD五分鐘動態資訊" u...
# 2                                              \t<Infos>
# 3      \t\t<Info vdid="nfbVD-N1-S--0.008-M-LOOP" stat...
# 4      \t\t\t<lane vsrdir="0" vsrid="1" speed="56" la...
# ...                                                  ...
# 48492         \t\t\t\t<cars carid="L" volume="0"></cars>
# 48493                                      \t\t\t</lane>
# 48494                                        \t\t</Info>
# 48495                                         \t</Infos>
# 48496                                        </XML_Head>
#
# [48497 rows x 1 columns]

# %%
df
# Out:
#                                                        0
# 0                 <?xml version="1.0" encoding="utf-8"?>
# 1      <XML_Head version="1.1" listname="VD五分鐘動態資訊" u...
# 2                                              \t<Infos>
# 3      \t\t<Info vdid="nfbVD-N1-S--0.008-M-LOOP" stat...
# 4      \t\t\t<lane vsrdir="0" vsrid="1" speed="56" la...
# ...                                                  ...
# 48492         \t\t\t\t<cars carid="L" volume="0"></cars>
# 48493                                      \t\t\t</lane>
# 48494                                        \t\t</Info>
# 48495                                         \t</Infos>
# 48496                                        </XML_Head>
#
# [48497 rows x 1 columns]
